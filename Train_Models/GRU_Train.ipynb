# %%
import pandas as pd
import numpy as np
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, GRU
import tensorflow as tf
from datetime import datetime
# Out:
# C:\Users\vivs_\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\vivs_\anaconda3\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
# C:\Users\vivs_\anaconda3\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:\n%s" %

# %%
dataset = read_csv("seg_data2.csv",
                   parse_dates={'ST' : ['StartTime']},
                   infer_datetime_format=True, 
                   index_col= 1,
                   na_values=['nan','?'])
dataset.fillna(0, inplace=True)
values = dataset.values

# %%
dataset.head(4)
# Out:
#                             ST        Start        EndTime       Speed
# SegmentId
# 1071707139 2021-07-06 00:00:00  44383.00000  7/6/2021 0:30   95.933333
# 1071707139 2021-07-06 00:30:00  44383.02083  7/6/2021 1:00  100.000000
# 1071707139 2021-07-06 01:00:00  44383.04167  7/6/2021 1:30   90.666667
# 1071707139 2021-07-06 01:30:00  44383.06250  7/6/2021 2:00  100.000000

# %%
dataset.drop(columns  = [ 'EndTime','ST'], inplace = True)
values = dataset.values
# ensure all data is float
values = values.astype('float32')

# %%
# normalizing input features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
scaled =pd.DataFrame(scaled)
scaled.head(4)
# Out:
#           0         1
# 0  0.000000  0.636190
# 1  0.019531  0.675056
# 2  0.042969  0.585855
# 3  0.062500  0.675056

# %%
def create_ts_data(dataset, lookback=1, predicted_col=2):
    temp=dataset.copy()
    temp["id"]= range(1, len(temp)+1)
    temp = temp.iloc[:-lookback, :]
    temp.set_index('id', inplace =True)
    predicted_value=dataset.copy()
    predicted_value = predicted_value.iloc[lookback:,predicted_col]
    predicted_value.columns=["Predcited"]
    predicted_value= pd.DataFrame(predicted_value)
    
    predicted_value["id"]= range(1, len(predicted_value)+1)
    predicted_value.set_index('id', inplace =True)
    final_df= pd.concat([temp, predicted_value], axis=1)
    #final_df.columns = ['var1(t-1)', 'var2(t-1)', 'var3(t-1)', 'var4(t-1)', 'var5(t-1)', 'var6(t-1)', 'var7(t-1)', 'var8(t-1)','var1(t)']
    #final_df.set_index('Date', inplace=True)
    return final_df

# %%
#We now create the time series dataset with looking back one time step

reframed_df= create_ts_data(scaled, 1,1)
reframed_df.fillna(0, inplace=True)

reframed_df.columns = ['var1(t-1)', 'var2(t-1)', 'var3(t-1)',]
print(reframed_df.head(4))
# Out:
#     var1(t-1)  var2(t-1)  var3(t-1)
# id
# 1    0.000000   0.636190   0.675056
# 2    0.019531   0.675056   0.585855
# 3    0.042969   0.585855   0.675056
# 4    0.062500   0.675056   0.675056

# %%
# split into train and test sets
values = reframed_df.values
training_sample =int( len(dataset) *0.7)
train = values[:training_sample, :]
test = values[training_sample:, :]
# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]

# %%
# reshape input to be 3D [samples, time steps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (6619, 1, 2) (6619,) (2836, 1, 2) (2836,)

# %%
model_gru = Sequential()
model_gru.add(GRU(120, return_sequences=True,input_shape=(train_X.shape[1], train_X.shape[2])))
model_gru.add(GRU(units=40, return_sequences=True))
model_gru.add(GRU(units=40))
model_gru.add(Dense(units=1))

model_gru.compile(loss='mae', optimizer='adam')
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 1, 120)            44640
# _________________________________________________________________
# gru_1 (GRU)                  (None, 1, 40)             19440
# _________________________________________________________________
# gru_2 (GRU)                  (None, 40)                9840
# _________________________________________________________________
# dense (Dense)                (None, 1)                 41
# =================================================================
# Total params: 73,961
# Trainable params: 73,961
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit network
gru_history = model_gru.fit(train_X, train_y, epochs=80,validation_data=(test_X, test_y), batch_size=64, shuffle=False)
# Out:
# Epoch 1/80
# 104/104 [==============================] - 16s 15ms/step - loss: 0.2792 - val_loss: 0.0728
# Epoch 2/80
# 104/104 [==============================] - 0s 2ms/step - loss: 0.0597 - val_loss: 0.0643
# Epoch 3/80
# 104/104 [==============================] - 0s 2ms/step - loss: 0.0584 - val_loss: 0.0632
# Epoch 4/80
# 104/104 [==============================] - 0s 2ms/step - loss: 0.0582 - val_loss: 0.0621
# Epoch 5/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0578 - val_loss: 0.0590
# Epoch 6/80
# 104/104 [==============================] - 0s 2ms/step - loss: 0.0573 - val_loss: 0.0645
# Epoch 7/80
# 104/104 [==============================] - 0s 2ms/step - loss: 0.0573 - val_loss: 0.0594
# Epoch 8/80
# 104/104 [==============================] - 0s 2ms/step - loss: 0.0569 - val_loss: 0.0599
# Epoch 9/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0568 - val_loss: 0.0605
# Epoch 10/80
# 104/104 [==============================] - 0s 2ms/step - loss: 0.0565 - val_loss: 0.0600
# Epoch 11/80
# 104/104 [==============================] - 0s 2ms/step - loss: 0.0563 - val_loss: 0.0595
# Epoch 12/80
# 104/104 [==============================] - 0s 2ms/step - loss: 0.0562 - val_loss: 0.0615
# Epoch 13/80
# 104/104 [==============================] - 0s 2ms/step - loss: 0.0563 - val_loss: 0.0614
# Epoch 14/80
# 104/104 [==============================] - 0s 2ms/step - loss: 0.0560 - val_loss: 0.0592
# Epoch 15/80
# 104/104 [==============================] - 0s 2ms/step - loss: 0.0557 - val_loss: 0.0597
# Epoch 16/80
# 104/104 [==============================] - 0s 2ms/step - loss: 0.0557 - val_loss: 0.0616
# Epoch 17/80
# 104/104 [==============================] - 0s 2ms/step - loss: 0.0558 - val_loss: 0.0607
# Epoch 18/80
# 104/104 [==============================] - 0s 2ms/step - loss: 0.0557 - val_loss: 0.0599
# Epoch 19/80
# 104/104 [==============================] - 0s 2ms/step - loss: 0.0556 - val_loss: 0.0586
# Epoch 20/80
# 104/104 [==============================] - 0s 2ms/step - loss: 0.0555 - val_loss: 0.0583
# Epoch 21/80
# 104/104 [==============================] - 0s 2ms/step - loss: 0.0552 - val_loss: 0.0581
# Epoch 22/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0553 - val_loss: 0.0592
# Epoch 23/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0556 - val_loss: 0.0581
# Epoch 24/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0551 - val_loss: 0.0584
# Epoch 25/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0553 - val_loss: 0.0585
# Epoch 26/80
# 104/104 [==============================] - 0s 2ms/step - loss: 0.0552 - val_loss: 0.0593
# Epoch 27/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0555 - val_loss: 0.0580
# Epoch 28/80
# 104/104 [==============================] - 0s 2ms/step - loss: 0.0549 - val_loss: 0.0585
# Epoch 29/80
# 104/104 [==============================] - 0s 2ms/step - loss: 0.0550 - val_loss: 0.0588
# Epoch 30/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0550 - val_loss: 0.0578
# Epoch 31/80
# 104/104 [==============================] - 0s 2ms/step - loss: 0.0548 - val_loss: 0.0585
# Epoch 32/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0552 - val_loss: 0.0589
# Epoch 33/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0551 - val_loss: 0.0580
# Epoch 34/80
# 104/104 [==============================] - 0s 2ms/step - loss: 0.0546 - val_loss: 0.0580
# Epoch 35/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0546 - val_loss: 0.0580
# Epoch 36/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0545 - val_loss: 0.0590
# Epoch 37/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0547 - val_loss: 0.0589
# Epoch 38/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0543 - val_loss: 0.0593
# Epoch 39/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0546 - val_loss: 0.0584
# Epoch 40/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0542 - val_loss: 0.0588
# Epoch 41/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0541 - val_loss: 0.0584
# Epoch 42/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0541 - val_loss: 0.0589
# Epoch 43/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0541 - val_loss: 0.0585
# Epoch 44/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0539 - val_loss: 0.0591
# Epoch 45/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0538 - val_loss: 0.0570
# Epoch 46/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0535 - val_loss: 0.0585
# Epoch 47/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0534 - val_loss: 0.0585
# Epoch 48/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0532 - val_loss: 0.0577
# Epoch 49/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0528 - val_loss: 0.0589
# Epoch 50/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0530 - val_loss: 0.0592
# Epoch 51/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0531 - val_loss: 0.0611
# Epoch 52/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0531 - val_loss: 0.0614
# Epoch 53/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0533 - val_loss: 0.0637
# Epoch 54/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0536 - val_loss: 0.0645
# Epoch 55/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0539 - val_loss: 0.0652
# Epoch 56/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0540 - val_loss: 0.0649
# Epoch 57/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0542 - val_loss: 0.0641
# Epoch 58/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0543 - val_loss: 0.0644
# Epoch 59/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0548 - val_loss: 0.0649
# Epoch 60/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0552 - val_loss: 0.0640
# Epoch 61/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0552 - val_loss: 0.0612
# Epoch 62/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0548 - val_loss: 0.0609
# Epoch 63/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0549 - val_loss: 0.0603
# Epoch 64/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0547 - val_loss: 0.0595
# Epoch 65/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0547 - val_loss: 0.0583
# Epoch 66/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0548 - val_loss: 0.0579
# Epoch 67/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0547 - val_loss: 0.0570
# Epoch 68/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0544 - val_loss: 0.0564
# Epoch 69/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0543 - val_loss: 0.0559
# Epoch 70/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0541 - val_loss: 0.0546
# Epoch 71/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0536 - val_loss: 0.0551
# Epoch 72/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0536 - val_loss: 0.0544
# Epoch 73/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0535 - val_loss: 0.0540
# Epoch 74/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0533 - val_loss: 0.0542
# Epoch 75/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0533 - val_loss: 0.0533
# Epoch 76/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0531 - val_loss: 0.0537
# Epoch 77/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0530 - val_loss: 0.0535
# Epoch 78/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0528 - val_loss: 0.0533
# Epoch 79/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0529 - val_loss: 0.0531
# Epoch 80/80
# 104/104 [==============================] - 0s 3ms/step - loss: 0.0528 - val_loss: 0.0530

# %%
pred_y =  model_gru.predict(test_X)

# %%
pyplot.plot(gru_history.history['loss'], label='lstm train', color='brown')
pyplot.plot(gru_history.history['val_loss'], label='lstm test', color='blue')
pyplot.legend()
pyplot.show()

# %%
test_y.reshape(2836,1)
# Out:
# array([[0.601784  ],
#        [0.7228416 ],
#        [0.6285441 ],
#        ...,
#        [0.65466714],
#        [0.54412234],
#        [0.562281  ]], dtype=float32)

# %%
pred_y
# Out:
# array([[0.68605334],
#        [0.6698316 ],
#        [0.6956742 ],
#        ...,
#        [0.6927978 ],
#        [0.68467706],
#        [0.6490094 ]], dtype=float32)

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (15,5)

from sklearn.metrics import *
from math import sqrt

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)

#plotting predicted test value vs actual test value
plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.005283121
# 0.41784068863881463
# 0.072685081135002
# 0.053006623

# %%
#visualization over full data
tra = np.concatenate([train_X,test_X])
tes = np.concatenate([train_y,test_y])
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()

# %%
#over small part of data
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()
