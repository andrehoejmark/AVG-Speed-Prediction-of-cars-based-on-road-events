# %%
import pandas as pd
import numpy as np
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM, GRU
import tensorflow as tf
from datetime import datetime
# Out:
# C:\Users\vivs_\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\vivs_\anaconda3\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
# C:\Users\vivs_\anaconda3\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:\n%s" %

# %%
dataset = read_csv("60min_Seg.csv",
                   parse_dates={'ST' : ['StartTime15']},
                   infer_datetime_format=True, 
                   index_col= 1,
                   na_values=['nan','?'])
dataset.fillna(0, inplace=True)
values = dataset.values

# %%
dataset.head(4)
# Out:
#                         ST       StartTime  StartTimeConv         EndTime  \
# SegmentId
# 226255131  43619.333333333   6/3/2019 8:00    43619.33333   6/3/2019 9:00
# 226255131        43619.375   6/3/2019 9:00    43619.37500  6/3/2019 10:00
# 226255131  43619.416666666  6/3/2019 10:00    43619.41667  6/3/2019 11:00
# 226255131  43619.458333333  6/3/2019 11:00    43619.45833  6/3/2019 12:00
#
#                Speed  Wind Direction  Wind Speed  Precipitation amount  \
# SegmentId
# 226255131  97.090909             138         5.1                   0.0
# 226255131  93.466667             180         8.4                   0.0
# 226255131  99.033898             179         8.2                   0.1
# 226255131  94.666667             185         8.0                   0.0
#
#           Quality  AirTemp  Snow_Depth  Ground_Cond
# SegmentId
# 226255131       G     14.1         0.0            0
# 226255131       G     17.4         0.0            0
# 226255131       G     17.5         0.0            0
# 226255131       G     17.5         0.0            0

# %%
dataset.drop(columns  = [ 'Quality','EndTime','StartTime','StartTimeConv','Ground_Cond','Snow_Depth','Precipitation amount'], inplace = True)
values = dataset.values
# ensure all data is float
values = values.astype('float32')

# %%
dataset.head(4)
# Out:
#                         ST      Speed  Wind Direction  Wind Speed  AirTemp
# SegmentId
# 226255131  43619.333333333  97.090909             138         5.1     14.1
# 226255131        43619.375  93.466667             180         8.4     17.4
# 226255131  43619.416666666  99.033898             179         8.2     17.5
# 226255131  43619.458333333  94.666667             185         8.0     17.5

# %%
# normalizing input features
scaler = MinMaxScaler(feature_range=(0, 4))
scaled = scaler.fit_transform(values)
scaled =pd.DataFrame(scaled)
scaled.head(4)
# Out:
#           0         1         2         3         4
# 0  0.000000  2.824810  1.533333  1.030303  2.533333
# 1  0.000183  2.711360  2.000000  1.696970  2.900000
# 2  0.000381  2.885631  1.988889  1.656566  2.911111
# 3  0.000549  2.748924  2.055556  1.616162  2.911111

# %%
def create_ts_data(dataset, lookback=1, predicted_col=2):
    temp=dataset.copy()
    temp["id"]= range(1, len(temp)+1)
    temp = temp.iloc[:-lookback, :]
    temp.set_index('id', inplace =True)
    predicted_value=dataset.copy()
    predicted_value = predicted_value.iloc[lookback:,predicted_col]
    predicted_value.columns=["Predcited"]
    predicted_value= pd.DataFrame(predicted_value)
    
    predicted_value["id"]= range(1, len(predicted_value)+1)
    predicted_value.set_index('id', inplace =True)
    final_df= pd.concat([temp, predicted_value], axis=1)
    #final_df.columns = ['var1(t-1)', 'var2(t-1)', 'var3(t-1)', 'var4(t-1)', 'var5(t-1)', 'var6(t-1)', 'var7(t-1)', 'var8(t-1)','var1(t)']
    #final_df.set_index('Date', inplace=True)
    return final_df

# %%
#We now create the time series dataset with looking back one time step

reframed_df= create_ts_data(scaled, 1,4)
reframed_df.fillna(0, inplace=True)

reframed_df.columns = ['var1(t-1)', 'var2(t-1)', 'var3(t-1)', 'var4(t-1)','var5(t-1)', 'var1(t)']
print(reframed_df.head(4))
# Out:
#     var1(t-1)  var2(t-1)  var3(t-1)  var4(t-1)  var5(t-1)   var1(t)
# id
# 1    0.000000   2.824810   1.533333   1.030303   2.533333  2.900000
# 2    0.000183   2.711360   2.000000   1.696970   2.900000  2.911111
# 3    0.000381   2.885631   1.988889   1.656566   2.911111  2.911111
# 4    0.000549   2.748924   2.055556   1.616162   2.911111  2.788889

# %%
# split into train and test sets
values = reframed_df.values
training_sample =int( len(dataset) *0.75)
train = values[:training_sample, :]
test = values[training_sample:, :]
# split into input and outputs
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]

# %%
# reshape input to be 3D [samples, time steps, features]
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
# Out:
# (16066, 1, 5) (16066,) (5355, 1, 5) (5355,)

# %%
model_gru = Sequential()
model_gru.add(GRU(384, return_sequences=True,input_shape=(train_X.shape[1], train_X.shape[2])))
model_gru.add(GRU(units=60, return_sequences=True))
model_gru.add(GRU(units=60))
model_gru.add(Dense(units=1))

model_gru.compile(loss='mae', optimizer='adam')
model_gru.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 1, 384)            450432
# _________________________________________________________________
# gru_1 (GRU)                  (None, 1, 60)             80280
# _________________________________________________________________
# gru_2 (GRU)                  (None, 60)                21960
# _________________________________________________________________
# dense (Dense)                (None, 1)                 61
# =================================================================
# Total params: 552,733
# Trainable params: 552,733
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit network
gru_history = model_gru.fit(train_X, train_y, epochs=100,validation_data=(test_X, test_y), batch_size=64, shuffle=False)
# Out:
# Epoch 1/100
# 252/252 [==============================] - 1s 6ms/step - loss: 0.0436 - val_loss: 0.1023
# Epoch 2/100
# 252/252 [==============================] - 1s 6ms/step - loss: 0.0428 - val_loss: 0.1066
# Epoch 3/100
# 252/252 [==============================] - 1s 6ms/step - loss: 0.0408 - val_loss: 0.0922
# Epoch 4/100
# 252/252 [==============================] - 2s 6ms/step - loss: 0.0430 - val_loss: 0.1082
# Epoch 5/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0443 - val_loss: 0.1214
# Epoch 6/100
# 252/252 [==============================] - 2s 8ms/step - loss: 0.0419 - val_loss: 0.0944
# Epoch 7/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0450 - val_loss: 0.0938
# Epoch 8/100
# 252/252 [==============================] - 2s 8ms/step - loss: 0.0444 - val_loss: 0.0960
# Epoch 9/100
# 252/252 [==============================] - 2s 8ms/step - loss: 0.0407 - val_loss: 0.1034
# Epoch 10/100
# 252/252 [==============================] - 2s 9ms/step - loss: 0.0424 - val_loss: 0.0952
# Epoch 11/100
# 252/252 [==============================] - 2s 8ms/step - loss: 0.0443 - val_loss: 0.1232
# Epoch 12/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0426 - val_loss: 0.1016
# Epoch 13/100
# 252/252 [==============================] - 2s 8ms/step - loss: 0.0427 - val_loss: 0.1018
# Epoch 14/100
# 252/252 [==============================] - 2s 8ms/step - loss: 0.0427 - val_loss: 0.0935
# Epoch 15/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0430 - val_loss: 0.1022
# Epoch 16/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0423 - val_loss: 0.0969
# Epoch 17/100
# 252/252 [==============================] - 2s 8ms/step - loss: 0.0421 - val_loss: 0.0981
# Epoch 18/100
# 252/252 [==============================] - 2s 9ms/step - loss: 0.0414 - val_loss: 0.0788
# Epoch 19/100
# 252/252 [==============================] - 2s 8ms/step - loss: 0.0419 - val_loss: 0.0716
# Epoch 20/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0437 - val_loss: 0.1052
# Epoch 21/100
# 252/252 [==============================] - 2s 8ms/step - loss: 0.0421 - val_loss: 0.0893
# Epoch 22/100
# 252/252 [==============================] - 2s 8ms/step - loss: 0.0424 - val_loss: 0.0882
# Epoch 23/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0404 - val_loss: 0.0931
# Epoch 24/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0421 - val_loss: 0.0883
# Epoch 25/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0423 - val_loss: 0.0921
# Epoch 26/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0450 - val_loss: 0.1096
# Epoch 27/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0402 - val_loss: 0.0932
# Epoch 28/100
# 252/252 [==============================] - 2s 8ms/step - loss: 0.0424 - val_loss: 0.0872
# Epoch 29/100
# 252/252 [==============================] - 2s 8ms/step - loss: 0.0426 - val_loss: 0.0926
# Epoch 30/100
# 252/252 [==============================] - 2s 8ms/step - loss: 0.0424 - val_loss: 0.0926
# Epoch 31/100
# 252/252 [==============================] - 2s 8ms/step - loss: 0.0442 - val_loss: 0.1024
# Epoch 32/100
# 252/252 [==============================] - 2s 8ms/step - loss: 0.0435 - val_loss: 0.0878
# Epoch 33/100
# 252/252 [==============================] - 2s 8ms/step - loss: 0.0415 - val_loss: 0.0831
# Epoch 34/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0417 - val_loss: 0.1040
# Epoch 35/100
# 252/252 [==============================] - 2s 8ms/step - loss: 0.0419 - val_loss: 0.0979
# Epoch 36/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0407 - val_loss: 0.0825
# Epoch 37/100
# 252/252 [==============================] - 2s 6ms/step - loss: 0.0422 - val_loss: 0.0853
# Epoch 38/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0425 - val_loss: 0.0836
# Epoch 39/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0411 - val_loss: 0.0813
# Epoch 40/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0421 - val_loss: 0.0852
# Epoch 41/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0418 - val_loss: 0.0849
# Epoch 42/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0420 - val_loss: 0.0886
# Epoch 43/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0400 - val_loss: 0.0817
# Epoch 44/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0419 - val_loss: 0.0745
# Epoch 45/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0420 - val_loss: 0.0783
# Epoch 46/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0424 - val_loss: 0.0815
# Epoch 47/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0419 - val_loss: 0.0750
# Epoch 48/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0449 - val_loss: 0.0852
# Epoch 49/100
# 252/252 [==============================] - 2s 8ms/step - loss: 0.0407 - val_loss: 0.0688
# Epoch 50/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0417 - val_loss: 0.0733
# Epoch 51/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0404 - val_loss: 0.0833
# Epoch 52/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0417 - val_loss: 0.0751
# Epoch 53/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0419 - val_loss: 0.0880
# Epoch 54/100
# 252/252 [==============================] - 2s 8ms/step - loss: 0.0415 - val_loss: 0.0760
# Epoch 55/100
# 252/252 [==============================] - 2s 8ms/step - loss: 0.0420 - val_loss: 0.0759
# Epoch 56/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0436 - val_loss: 0.0747
# Epoch 57/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0411 - val_loss: 0.0710
# Epoch 58/100
# 252/252 [==============================] - 2s 8ms/step - loss: 0.0416 - val_loss: 0.0639
# Epoch 59/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0395 - val_loss: 0.0670
# Epoch 60/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0410 - val_loss: 0.0704
# Epoch 61/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0413 - val_loss: 0.0747
# Epoch 62/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0410 - val_loss: 0.0673
# Epoch 63/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0417 - val_loss: 0.0603
# Epoch 64/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0414 - val_loss: 0.0713
# Epoch 65/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0406 - val_loss: 0.0808
# Epoch 66/100
# 252/252 [==============================] - 2s 8ms/step - loss: 0.0405 - val_loss: 0.0532
# Epoch 67/100
# 252/252 [==============================] - 2s 8ms/step - loss: 0.0417 - val_loss: 0.0689
# Epoch 68/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0399 - val_loss: 0.0714
# Epoch 69/100
# 252/252 [==============================] - 2s 8ms/step - loss: 0.0405 - val_loss: 0.0577
# Epoch 70/100
# 252/252 [==============================] - 2s 8ms/step - loss: 0.0422 - val_loss: 0.0622
# Epoch 71/100
# 252/252 [==============================] - 2s 8ms/step - loss: 0.0397 - val_loss: 0.0649
# Epoch 72/100
# 252/252 [==============================] - 2s 8ms/step - loss: 0.0398 - val_loss: 0.0703
# Epoch 73/100
# 252/252 [==============================] - 2s 6ms/step - loss: 0.0427 - val_loss: 0.0740
# Epoch 74/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0405 - val_loss: 0.0682
# Epoch 75/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0408 - val_loss: 0.0557
# Epoch 76/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0409 - val_loss: 0.0678
# Epoch 77/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0406 - val_loss: 0.0567
# Epoch 78/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0414 - val_loss: 0.0540
# Epoch 79/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0408 - val_loss: 0.0565
# Epoch 80/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0406 - val_loss: 0.0722
# Epoch 81/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0394 - val_loss: 0.0560
# Epoch 82/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0394 - val_loss: 0.0556
# Epoch 83/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0419 - val_loss: 0.0615
# Epoch 84/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0400 - val_loss: 0.0620
# Epoch 85/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0409 - val_loss: 0.0591
# Epoch 86/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0452 - val_loss: 0.0662
# Epoch 87/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0407 - val_loss: 0.0638
# Epoch 88/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0437 - val_loss: 0.0679
# Epoch 89/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0432 - val_loss: 0.0740
# Epoch 90/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0416 - val_loss: 0.0748
# Epoch 91/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0424 - val_loss: 0.0783
# Epoch 92/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0435 - val_loss: 0.0632
# Epoch 93/100
# 252/252 [==============================] - 2s 8ms/step - loss: 0.0400 - val_loss: 0.0726
# Epoch 94/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0395 - val_loss: 0.0737
# Epoch 95/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0424 - val_loss: 0.0999
# Epoch 96/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0430 - val_loss: 0.0823
# Epoch 97/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0440 - val_loss: 0.0776
# Epoch 98/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0441 - val_loss: 0.0713
# Epoch 99/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0431 - val_loss: 0.0734
# Epoch 100/100
# 252/252 [==============================] - 2s 7ms/step - loss: 0.0433 - val_loss: 0.0777

# %%
pred_y =  model_gru.predict(test_X)

# %%
pyplot.plot(gru_history.history['loss'], label='GRU train', color='brown')
pyplot.plot(gru_history.history['val_loss'], label='GRU test', color='blue')
pyplot.legend()
pyplot.show()

# %%
test_y.reshape(5355,1)
# Out:
# array([[1.2444444 ],
#        [1.1999999 ],
#        [1.2111111 ],
#        ...,
#        [0.7888889 ],
#        [0.76666665],
#        [0.82222223]], dtype=float32)

# %%
pred_y
# Out:
# array([[1.2568507 ],
#        [1.2576271 ],
#        [1.2147117 ],
#        ...,
#        [0.73751616],
#        [0.74932635],
#        [0.72562873]], dtype=float32)

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (10,5)

from sklearn.metrics import *
from math import sqrt

MSE = mean_squared_error(test_y, pred_y)
R2 = r2_score(test_y, pred_y)
RMSE = sqrt(mean_squared_error(test_y, pred_y))
MAE = mean_absolute_error(test_y, pred_y)


print(MSE)
print(R2)
print(RMSE)
print(MAE)

#plotting predicted test value vs actual test value
plt.plot(test_y, label = 'Actual')
plt.plot(pred_y, label = 'Predicted')
plt.legend()
plt.show()
# Out:
# 0.00992352
# 0.9733456497459999
# 0.09961686386679296
# 0.07769492

# %%
#visualization over full data
tra = test_X
tes = test_y
fp = model_gru.predict(tra)
plt.plot(tes, label = 'Actual')
plt.plot(fp, label = 'Predicted')
plt.legend()
plt.show()

# %%
#over small part of data
plt.plot(tes[:2000], label = 'Actual')
plt.plot(fp[:2000], label = 'Predicted')
plt.legend()
plt.show()
